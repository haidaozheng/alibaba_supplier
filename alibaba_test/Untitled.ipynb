# %%
a = 1
for i in range(3):
    a = i
print(a)
# Out:
# 2

# %%
a = {}
for i in range(4):
    a['num'] = i
print(a)
# Out:
# {'num': 3}

# %%
url = 'https://viewstart.en.alibaba.com/company_profile.html#top-nav-bar'
url
# Out:
# 'https://viewstart.en.alibaba.com/company_profile.html#top-nav-bar'

# %%
import re

# %%
print(re.search(r'https://(.+?)\.',url).group(1))
# Out:
# viewstart

# %%
list = ['hh ddf','sdf','aa s d','dfsdfa ssss']

# %%
[s.replace(' ','+') for s in list]
# Out:
# ['hh+ddf', 'sdf', 'aa+s+d', 'dfsdfa+ssss']

# %%
import pandas as pd

# %%
search_list = pd.read_csv('search_list.csv')

# %%
search_list
# Out:
#      search_list
# 0    phone glass
# 1         shooes
# 2  dresses women

# %%
search_list['search_list']
# Out:
# 0      phone glass
# 1           shooes
# 2    dresses women
# Name: search_list, dtype: object

# %%
[s.replace(' ','+') for s in search_list['search_list']]
# Out:
# ['phone+glass', 'shooes', 'dresses+women']

# %%
url_head = 'https://www.alibaba.com/trade/search?fsb=y&IndexArea=product_en&CatId=&SearchText='
url_tail = '&viewtype=L'

# %%
[url_head + s.replace(' ','+') + url_tail for s in search_list['search_list']]
# Out:
# ['https://www.alibaba.com/trade/search?fsb=y&IndexArea=product_en&CatId=&SearchText=phone+glass&viewtype=L',
#  'https://www.alibaba.com/trade/search?fsb=y&IndexArea=product_en&CatId=&SearchText=shooes&viewtype=L',
#  'https://www.alibaba.com/trade/search?fsb=y&IndexArea=product_en&CatId=&SearchText=dresses+women&viewtype=L']

# %%
for li in search_list['search_list']:
    print(li)
# Out:
# phone glass
# shooes
# dresses women

# %%
suppliers = pd.read_json('suppliers.json')

# %%
suppliers
# Out:
#                                           BusinessType  \
# 0                        Manufacturer, Trading Company
# 1                                      Trading Company
# 2                        Manufacturer, Trading Company
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                      Trading Company
# 9                                                  NaN
# 10   Manufacturer, Trading Company, Distributor/Who...
# 11                                                 NaN
# 12   Manufacturer, Trading Company, Distributor/Who...
# 13                                     Trading Company
# 14                                     Trading Company
# 15                                        Manufacturer
# ...
